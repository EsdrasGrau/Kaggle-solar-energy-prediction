# %%
import pandas as pd

# %%
df = pd.read_csv('sweet.csv', encoding='UTF-16', sep = '\t')

# %%
df
# Out:
#         Date      Time    Time Zone Gross Sales Discounts Net Sales  \
# 0   05/08/20  23:59:34  Mexico City        ¥867        ¥0      ¥867
# 1   05/08/20  23:56:56  Mexico City        ¥851        ¥0      ¥851
# 2   05/08/20  23:48:55  Mexico City      ¥1,331        ¥0    ¥1,331
# 3   05/08/20  23:36:51  Mexico City        ¥835        ¥0      ¥835
# 4   05/08/20  23:35:56  Mexico City        ¥638        ¥0      ¥638
# ..       ...       ...          ...         ...       ...       ...
# 81  05/08/20  00:39:11  Mexico City        ¥722        ¥0      ¥722
# 82  05/08/20  00:31:52  Mexico City        ¥741        ¥0      ¥741
# 83  05/08/20  00:26:44  Mexico City      ¥1,396        ¥0    ¥1,396
# 84  05/08/20  00:19:59  Mexico City      ¥2,122        ¥0    ¥2,122
# 85  05/08/20  00:05:47  Mexico City        ¥527        ¥0      ¥527
#
#    Gift Card Sales   Tax Tip Partial Refunds  ... Device Nickname Deposit ID  \
# ...
